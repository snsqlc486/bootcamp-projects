# %% [markdown]
# 데이터 수집 및 전처리 코드는 파일이 큰 관계로 시험용으로 구성된 전체 코드만 제공됩니다.

# %% [markdown]
# # 기초 데이터 수집

# %% [markdown]
# ## TMDB 데이터 수집

# %%
import file_collector.tmdb_collector as tdc
import time
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import warnings

warnings.filterwarnings("ignore")

# %%
start_date = '2025-11-01'
end_date = '2025-11-10'

OUTPUT_DIR = "files"

# %% [markdown]
# ### 영화

# %%
if __name__ == "__main__":
    total_start = time.time()

    # 기간을 3개월 단위로 분할
    periods = tdc.generate_date_periods(start_date, end_date, months=3)

    print(f"\n전체 기간: {start_date} ~ {end_date}")
    print(f"분할 기간: {len(periods)}개")
    print("="*90)

    # ID 데이터를 집합으로 변환하여 중복 제거
    all_ids = set()

    for idx, (period_start, period_end) in enumerate(periods, 1):
        print(f"\n[{idx}/{len(periods)}] 기간: {period_start} ~ {period_end}")

        # 기간내 영화 ID 수집
        current_ids_set = tdc.collect_movie_ids(period_start, period_end)
        # ID를 집합에 추가
        all_ids.update(current_ids_set)

        print(f"해당 기간 내 수집된 ID: {len(current_ids_set):,}개 (누적 ID: {len(all_ids):,}개)")

    # 집합을 리스트로 변환
    id_list = list(all_ids)

    print(f"\n{'='*90}")
    print(f"최종 ID 개수: {len(id_list):,}개")

    print(f"\n{'='*90}")
    print("상세 정보 멀티스레드 수집 시작...\n")

    results = []
    # 3. 상세 정보 수집 단계: ID 리스트를 사용
    with ThreadPoolExecutor(max_workers=30) as executor:
        # 딕셔너리 대신 ID 자체를 future에 매핑
        futures = {executor.submit(tdc.fetch_movie_details, movie_ids): movie_ids for movie_ids in id_list}

        for future in tqdm(as_completed(futures), total=len(futures), desc="영화 상세 수집"):
            detail = future.result()
            if detail:
                results.append(detail)

    print(f"\n상세 정보 수집 완료: {len(results):,}개")

    # 저장
    df = pd.DataFrame(results)
    # 컬럼 이름이 'first_air_date'라고 가정
    df = df.sort_values(["release_date", "popularity"], ascending=[True, False])
    df.to_csv(f"{OUTPUT_DIR}/movies_test.csv", index=False, encoding="utf-8-sig")

    elapsed = time.time() - total_start

    print("\n" + "="*90)
    print("========================== DONE ==========================")
    print(f"총 데이터: {len(df):,}개")
    print(f"소요시간: {elapsed/60:.2f}분 ({elapsed:.2f}초)")
    print(f"저장 파일: movies.csv")
    print("="*90)
# Out:
# 전체 기간: 2025-11-01 ~ 2025-11-10
# 분할 기간: 1개
# ==========================================================================================
#
# [1/1] 기간: 2025-11-01 ~ 2025-11-10
#
# ============================================================
# 📺 영화 ID 수집: 2025-11-01 ~ 2025-11-10
# ============================================================
#
# [기간 1/1] 2025-11-01 ~ 2025-11-10
#   [영화] 총 1,513개 (76페이지) → 수집: 76페이지
#   누적 ID: 1,513개
#
# ============================================================
# 최종 수집: 1,513개 영화 ID
# ============================================================
#
# 해당 기간 내 수집된 ID: 1,513개 (누적 ID: 1,513개)
#
# ==========================================================================================
# 최종 ID 개수: 1,513개
#
# ==========================================================================================
# 상세 정보 멀티스레드 수집 시작...
# 영화 상세 수집: 100%|██████████| 1513/1513 [00:26<00:00, 57.78it/s]
# 상세 정보 수집 완료: 1,513개
#
# ==========================================================================================
# ========================== DONE ==========================
# 총 데이터: 1,513개
# 소요시간: 0.48분 (28.86초)
# 저장 파일: movies.csv
# ==========================================================================================

# %% [markdown]
# ### 드라마

# %%
if __name__ == "__main__":
    total_start = time.time()

    # 기간을 N개월 단위로 분할
    periods = tdc.generate_date_periods(start_date, end_date, months=12)

    print(f"\n전체 기간: {start_date} ~ {end_date}")
    print(f"분할 기간: {len(periods)}개")
    print("=" * 90)

    # ID 데이터를 집합으로 변환하여 중복 제거
    all_ids = set()

    for idx, (period_start, period_end) in enumerate(periods, 1):
        print(f"\n[{idx}/{len(periods)}] 기간: {period_start} ~ {period_end}")

        # 기간내 TV 시리즈 ID 수집
        current_ids_set = tdc.collect_tv_ids(period_start, period_end)
        all_ids.update(current_ids_set)

        print(f"해당 기간 내 수집된 ID: {len(current_ids_set):,}개 (누적 ID: {len(all_ids):,}개)")

    # 집합을 리스트로 변환
    id_list = sorted(list(all_ids))

    print(f"\n{'=' * 90}")
    print(f"최종 ID 개수: {len(id_list):,}개")

    # ============================================================
    # 2단계: TV 시리즈 + 시즌 상세 정보 수집 (멀티스레드)
    # ============================================================
    print(f"\n{'=' * 90}")
    print("상세 정보 멀티스레드 수집 시작...\n")

    series_results = []
    seasons_results = []

    with ThreadPoolExecutor(max_workers=20) as executor:
        # 시리즈 + 시즌 동시 수집
        futures = {
            executor.submit(tdc.fetch_tv_series_and_seasons, tv_id): tv_id
            for tv_id in id_list
        }

        for future in tqdm(as_completed(futures), total=len(futures), desc="TV 시리즈 + 시즌 수집"):
            try:
                series_data, seasons_list = future.result()

                if series_data:
                    series_results.append(series_data)

                if seasons_list:
                    seasons_results.extend(seasons_list)

            except Exception as e:
                tv_id = futures[future]
                print(f"오류 (TV ID: {tv_id}): {e}")

    print(f"\n시리즈 정보 수집 완료: {len(series_results):,}개")
    print(f"시즌 정보 수집 완료: {len(seasons_results):,}개")

    # ============================================================
    # 3단계: 저장
    # ============================================================

    # 시리즈 데이터 저장
    df_series = pd.DataFrame(series_results)
    df_series = df_series.sort_values(["first_air_date", "popularity"], ascending=[True, False])

    # 시즌 데이터 저장
    df_seasons = pd.DataFrame(seasons_results)
    df_seasons = df_seasons.sort_values(["series_id", "season_number"], ascending=[True, True])

    # CSV 저장
    df_series.to_csv(f"{OUTPUT_DIR}/tv_series_test.csv", index=False, encoding="utf-8-sig")
    df_seasons.to_csv(f"{OUTPUT_DIR}/tv_seasons_test.csv", index=False, encoding="utf-8-sig")

    elapsed = time.time() - total_start

    print("\n" + "=" * 90)
    print("========================== DONE ==========================")
    print(f"시리즈 데이터: {len(df_series):,}개")
    print(f"시즌 데이터: {len(df_seasons):,}개")
    print(f"소요시간: {elapsed / 60:.2f}분 ({elapsed:.2f}초)")
    print(f"저장 파일: tv_series_test.csv, tv_seasons_test.csv")
    print("=" * 90)
# Out:
# 전체 기간: 2025-11-01 ~ 2025-11-10
# 분할 기간: 1개
# ==========================================================================================
#
# [1/1] 기간: 2025-11-01 ~ 2025-11-10
#
# ============================================================
# 📺 TV 시리즈 ID 수집: 2025-11-01 ~ 2025-11-10
# ============================================================
#
# [기간 1/1] 2025-11-01 ~ 2025-11-10
#   [TV 시리즈] 총 384개 (20페이지) → 수집: 20페이지
#   누적 ID: 384개
#
# ============================================================
# 최종 수집: 384개 TV 시리즈 ID
# ============================================================
#
# 해당 기간 내 수집된 ID: 384개 (누적 ID: 384개)
#
# ==========================================================================================
# 최종 ID 개수: 384개
#
# ==========================================================================================
# 상세 정보 멀티스레드 수집 시작...
# TV 시리즈 + 시즌 수집: 100%|██████████| 384/384 [00:12<00:00, 29.82it/s]
# 시리즈 정보 수집 완료: 384개
# 시즌 정보 수집 완료: 388개
#
# ==========================================================================================
# ========================== DONE ==========================
# 시리즈 데이터: 384개
# 시즌 데이터: 388개
# 소요시간: 0.23분 (13.97초)
# 저장 파일: tv_series_test.csv, tv_seasons_test.csv
# ==========================================================================================

# %% [markdown]
# ## IMDB 데이터 수집

# %%
import pandas as pd
import file_collector.imdb_collector as idc
import os

output_dir = f"{OUTPUT_DIR}/reviews"
os.makedirs(output_dir, exist_ok=True)

# %%
await idc.collect_imdb_reviews(
    input_csv_path=f"{OUTPUT_DIR}/movies_test.csv",   # 아까 만든 5035편 리스트
    output_csv_path=f"{OUTPUT_DIR}/reviews/movies_reviews_test.csv",   # 최종 리뷰 파일
    max_titles=None,               # 전체 5035편 다 돌리기
    max_reviews_per_title=None     # 영화당 리뷰 전부 수집
)
# Out:
# ======================================================================
# 🚀 IMDb 리뷰 크롤링 시작
# 📂 입력: files/movies_test.csv
# 💾 출력: files/reviews/movies_reviews_test.csv
# ======================================================================
# 🎯 이번에 수집할 영화 수: 477
# ➖ Maria Vitória (tt33053905) 리뷰 없음
# ✅ Royal Runaways (tt10522278)  8/8개
# ➖ Hate Thyself (tt30526409) 리뷰 없음
# ➖ Race/America (tt36386809) 리뷰 없음
# ➖ Sottopelle (tt8962670) 리뷰 없음
# ➖ Cold White (tt33354418) 리뷰 없음
# ➖ Bimba (tt38624836) 리뷰 없음
# ➖ Watch the Skies (tt6267164) 리뷰 없음
# ➖ Os Perebas (tt10750578) 리뷰 없음
# ➖ Jastimari (tt35295423) 리뷰 없음
# 💾 배치 저장: 8개 리뷰
# 📊 진행 상황: 10/477 (경과 0.0분)
# ✅ Christmas in the Ballroom (tt37991625)  2/2개
# ✅ Christmas on Duty (tt37133902)  16/16개
# ✅ Patty Is Such a Girly Name (tt37530747)  1/1개
# ➖ Mega Trump (tt36890106) 리뷰 없음
# ➖ Bystander (tt31796702) 리뷰 없음
# ➖ Além do Horizonte - A Travessia (tt37540645) 리뷰 없음
# ✅ The Christmas Bookshop (tt35326037)  7/7개
# ➖ The Garden (tt38999706) 리뷰 없음
# ➖ Detox Inn (tt33098202) 리뷰 없음
# ➖ What If the Future Never Happened? (tt21060054) 리뷰 없음
# 💾 배치 저장: 26개 리뷰
# 📊 진행 상황: 20/477 (경과 0.1분)
# ➖ Noah's Daughter (tt38589225) 리뷰 없음
# ➖ Roubo do Cão (tt37458189) 리뷰 없음
# ➖ Linka Linka (tt38574217) 리뷰 없음
# ✅ Idaho Fallen (tt27135110)  3/3개
# ✅ Exes of Christmas Past (tt36120732)  13/13개
# ✅ Christmas in Midnight Clear (tt37714907)  6/6개
# ✅ What About Your Friends? (tt37675330)  2/2개
# ➖ Christmas at Fields Ranch (tt37964718) 리뷰 없음
# ✅ Casefield (tt27840481)  4/4개
# ➖ The Best of BandLab (tt38821008) 리뷰 없음
# 💾 배치 저장: 28개 리뷰
# 📊 진행 상황: 30/477 (경과 0.1분)
# ➖ Madriguera (tt38839020) 리뷰 없음
# ➖ Nilgün (tt39053050) 리뷰 없음
# ✅ Christmas Roses (tt36735046)  5/5개
# ✅ Christmas of Giving (tt37674795)  8/8개
# ✅ 12 Toys of Christmas (tt30317277)  1/1개
# ➖ Strawberry Sweet Killers (tt35628874) 리뷰 없음
# ➖ The Unsinkable Entrepreneur (tt18555610) 리뷰 없음
# ➖ Type of Rain (tt33048553) 리뷰 없음
# ➖ Nixon (tt38812970) 리뷰 없음
# ➖ Inferno (tt38004025) 리뷰 없음
# 💾 배치 저장: 14개 리뷰
# 📊 진행 상황: 40/477 (경과 0.2분)
# ➖ Eudaimonia (tt35668876) 리뷰 없음
# ➖ Journey into Sato Tadao (tt38589185) 리뷰 없음
# ➖ Para atrapar el viento (tt39141835) 리뷰 없음
# ➖ Savage (tt38720781) 리뷰 없음
# ➖ ASALI: Power of the Pollinators (tt22897634) 리뷰 없음
# ➖ Die Anden - Im Bann der Urkräfte (tt38813706) 리뷰 없음
# ➖ Echoes of an Outlaw (tt32295906) 리뷰 없음
# ➖ Die Frau ohne Gesicht (tt38585456) 리뷰 없음
# ➖ Harder and Harder (tt37284228) 리뷰 없음
# ➖ I Study People For A Living (tt36708708) 리뷰 없음
# 📊 진행 상황: 50/477 (경과 0.2분)
# ➖ Hyde (tt3712038) 리뷰 없음
# ➖ Fire in the Pond (tt36621692) 리뷰 없음
# ➖ Tender (tt35561269) 리뷰 없음
# ✅ Skweezy Jibbs Makes a Movie (tt37656190)  12/12개
# ➖ Tosca (tt39215190) 리뷰 없음
# ➖ Subject (tt38594171) 리뷰 없음
# ➖ Rando (tt38592102) 리뷰 없음
# ✅ A Dairy Story (tt38075983)  3/3개
# ➖ The Old Man and His Car (tt38589232) 리뷰 없음
# ➖ Hôtel de la Paix (tt37676715) 리뷰 없음
# 💾 배치 저장: 15개 리뷰
# 📊 진행 상황: 60/477 (경과 0.3분)
# ➖ Barber of the Gods (tt37829516) 리뷰 없음
# ✅ The Great Christmas Snow-In (tt31520670)  10/10개
# ✅ Mahi (tt36435448)  1/1개
# ➖ Birthday Cake (tt33366377) 리뷰 없음
# ➖ About Me (tt38593835) 리뷰 없음
# ➖ HOLE (tt38837903) 리뷰 없음
# ➖ Jeggies (tt29594323) 리뷰 없음
# ✅ My Brother, My Brother (tt35257962)  11/11개
# ➖ Red Harvest (tt38840823) 리뷰 없음
# ✅ A Newport Christmas (tt36491858)  32/32개
# 💾 배치 저장: 54개 리뷰
# 📊 진행 상황: 70/477 (경과 0.3분)
# ➖ Até o Caroço (tt31132556) 리뷰 없음
# ➖ 11-99 (tt39108849) 리뷰 없음
# ➖ One of Us (tt38350467) 리뷰 없음
# ➖ Project Eggman (tt36988273) 리뷰 없음
# ➖ Stuck in the Desert (tt38865418) 리뷰 없음
# ➖ What a Day, What a Life (tt39012292) 리뷰 없음
# ➖ Riding Time (tt39212734) 리뷰 없음
# ➖ To Kill the Chicken (tt31956440) 리뷰 없음
# ➖ Turboplatino (tt29237603) 리뷰 없음
# ✅ Dr. Seuss's The Sneetches (tt37677952)  1/1개
# 💾 배치 저장: 1개 리뷰
# 📊 진행 상황: 80/477 (경과 0.4분)
# ➖ Amalgam (tt28279347) 리뷰 없음
# ✅ 260 days (tt32599834)  10/10개
# ✅ Fest Godzilla II: Shinjuku Burning (tt38843905)  2/2개
# ➖ Don't Come Here (tt13774242) 리뷰 없음
# ✅ Leanne Morgan: Unspeakable Things (tt38061951)  3/3개
# ✅ Christmas at Mistletoe Hall (tt38786801)  2/2개
# ➖ Mommy's Boys (tt38693799) 리뷰 없음
# ✅ Roses on the Vine (tt27693622)  1/1개
# ➖ Far in the Middle of the East (tt38589196) 리뷰 없음
# ➖ Roberto Rossellini - Più di una vita (tt39060313) 리뷰 없음
# 💾 배치 저장: 18개 리뷰
# 📊 진행 상황: 90/477 (경과 0.4분)
# ➖ The Café (tt19796630) 리뷰 없음
# ➖ The Great American Baking Show: Celebrity Holiday 2025 (tt38773437) 리뷰 없음
# ➖ Sleeppers (tt38721761) 리뷰 없음
# ➖ Soulmatch (tt38720853) 리뷰 없음
# ➖ 13 novembre, nos vies en éclats (tt39131615) 리뷰 없음
# ➖ Big Leather: Lemon Lanes (tt38517040) 리뷰 없음
# ➖ Bis auf weiteres unsterblich (tt33131495) 리뷰 없음
# ➖ Two Days on the Interstate (tt38178488) 리뷰 없음
# ✅ Predator: Wastelands (tt37506041)  20/20개
# ➖ Another Man (tt33131733) 리뷰 없음
# 💾 배치 저장: 20개 리뷰
# 📊 진행 상황: 100/477 (경과 0.5분)
# ➖ Gamer Girls (tt36304379) 리뷰 없음
# ➖ The Fall of Prince Andrew (tt38854588) 리뷰 없음
# ➖ Confessions in Static (tt36590606) 리뷰 없음
# ➖ A Loud Piece of Armour (tt33294377) 리뷰 없음
# ✅ Two Black Boys in Paradise (tt27449033)  1/1개
# ➖ Nightfall (tt37071129) 리뷰 없음
# ✅ The Caretaker (tt33713724)  8/8개
# ➖ His Princess from Nowhere (tt38823329) 리뷰 없음
# ✅ I Will Love You in November (tt38693953)  1/1개
# ✅ Sense & Sensibility: A Modern Retelling (tt34498581)  35/35개
# 💾 배치 저장: 45개 리뷰
# 📊 진행 상황: 110/477 (경과 0.5분)
# ➖ A Chrismystery (tt34381479) 리뷰 없음
# ✅ Harry Chapin - Cat’s in the Cradle: The Song That Changed Our Lives (tt38941617)  1/1개
# ✅ The Town that Cried Wolf (tt38782595)  2/2개
# ➖ Sursum Corda, amore (tt33455320) 리뷰 없음
# ➖ The Rise of Germany’s New Right (tt65544662) 리뷰 없음
# ➖ Hugs (tt39026975) 리뷰 없음
# ➖ Cries (tt38778002) 리뷰 없음
# ✅ Playdate (tt31425731)  268/268개
# ✅ Train Dreams (tt29768334)  290/290개
# ✅ Predator: Badlands (tt31227572)  981/981개
# 💾 배치 저장: 1542개 리뷰
# 📊 진행 상황: 120/477 (경과 1.1분)
# ✅ Ablaze (tt35522328)  1/1개
# ➖ Class Reunion (tt21068440) 리뷰 없음
# ✅ Mean Boys (tt14371268)  1/1개
# ➖ The Favor (tt36795341) 리뷰 없음
# ➖ Slide (tt14443692) 리뷰 없음
# ➖ Kika (tt33400055) 리뷰 없음
# ➖ 404 Still Remain (tt38133008) 리뷰 없음
# ➖ Electra7 (tt38552382) 리뷰 없음
# ➖ The Great Arch (tt32398150) 리뷰 없음
# ✅ Tyler Perry's Finding Joy (tt31193547)  41/41개
# 💾 배치 저장: 43개 리뷰
# 📊 진행 상황: 130/477 (경과 1.1분)
# ✅ SAVE (tt38873863)  1/1개
# ➖ Deli Meat (tt30857176) 리뷰 없음
# ➖ The Finder (tt38935199) 리뷰 없음
# ➖ Ghost Fish (tt39011688) 리뷰 없음
# ➖ The Pasha's Palace (tt35294169) 리뷰 없음
# ➖ Scammers (tt38875379) 리뷰 없음
# ➖ The Jezebels (tt38037118) 리뷰 없음
# ➖ Regan (tt37721761) 리뷰 없음
# ➖ Spacetime Chronicles (tt37482911) 리뷰 없음
# ➖ The Red Box Project (tt26928676) 리뷰 없음
# 💾 배치 저장: 1개 리뷰
# 📊 진행 상황: 140/477 (경과 1.2분)
# ➖ Noah Britton: The Best Stuff I've Ever Done (tt38390416) 리뷰 없음
# ➖ La Jetée: The Fifth Shot (tt32134829) 리뷰 없음
# ➖ Life in a Beat (tt36347581) 리뷰 없음
# ➖ The Thread (tt39215113) 리뷰 없음
# ➖ Madonna Mia (tt36112792) 리뷰 없음
# ➖ JunkieLove (tt34313756) 리뷰 없음
# ✅ Die by Law (tt38796175)  1/1개
# ➖ The One and Only Fan (tt37024791) 리뷰 없음
# ➖ Girls Don't Breathe (tt38691493) 리뷰 없음
# ➖ Koss Gina Mistake (tt37320616) 리뷰 없음
# 💾 배치 저장: 1개 리뷰
# 📊 진행 상황: 150/477 (경과 1.2분)
# ➖ Do You See When Things Change? (tt37255696) 리뷰 없음
# ➖ The Weight of the Moon (tt39000663) 리뷰 없음
# ➖ GG (tt30766375) 리뷰 없음
# ➖ caretaker.majd.investigates (tt35323958) 리뷰 없음
# ➖ Entangled (tt38748425) 리뷰 없음
# ➖ Baroudeurs du Christ (tt38553252) 리뷰 없음
# ✅ Ko Ga Loak Village (tt35020020)  2/2개
# ✅ The Surrender (tt33270263)  32/32개
# ✅ Christy (tt32323252)  100/100개
# ✅ Nuremberg (tt29567915)  261/261개
# 💾 배치 저장: 395개 리뷰
# 📊 진행 상황: 160/477 (경과 1.4분)
# ✅ A Mouse Hunt for Christmas (tt35727399)  1/1개
# ✅ Wicked: One Wonderful Night (tt36963991)  9/9개
# ✅ Groom & Two Brides (tt35713227)  4/4개
# ➖ Kuncen (tt31601350) 리뷰 없음
# ✅ The Disinvited (tt22060390)  3/3개
# ✅ Banduan (tt38047685)  5/5개
# ✅ Just Breathe (tt28480494)  10/10개
# ✅ Mango (tt33293169)  6/6개
# ✅ Sarah's Oil (tt31727267)  27/27개
# ✅ Baramulla (tt29247040)  323/323개
# 💾 배치 저장: 388개 리뷰
# 📊 진행 상황: 170/477 (경과 1.6분)
# ➖ Mayflies (tt29115034) 리뷰 없음
# ✅ On Your Lap (tt34375730)  3/3개
# ➖ Anna (tt36911433) 리뷰 없음
# ➖ Sosok Ketiga: Lintrik (tt36257250) 리뷰 없음
# ➖ Retratos del Apocalipsis (tt34602203) 리뷰 없음
# ✅ Red Stars Upon the Field (tt35150158)  1/1개
# ✅ Escape Net (tt32610888)  4/4개
# ✅ Karen Kingsbury's The Christmas Ring (tt37282369)  9/9개
# ➖ Merhaba Tatlım (tt12526478) 리뷰 없음
# ✅ Mission Santa: Yoyo to the Rescue (tt35820129)  196/196개
# 💾 배치 저장: 213개 리뷰
# 📊 진행 상황: 180/477 (경과 1.7분)
# ➖ Sturmtief - Der Usedom-Krimi (tt38523062) 리뷰 없음
# ➖ Truth or Dare (tt27302416) 리뷰 없음
# ➖ Огненный мальчик (tt32495152) 리뷰 없음
# ➖ The Wound (tt30976412) 리뷰 없음
# ✅ Frankenstein: The Anatomy Lesson (tt38906516)  2/2개
# ✅ Augurk aan Zee (tt34376815)  2/2개
# ➖ Una famiglia sottosopra (tt34621452) 리뷰 없음
# ➖ The Unspoken (tt37814717) 리뷰 없음
# ✅ Animals in War (tt32203874)  1/1개
# ➖ Fwends (tt35439830) 리뷰 없음
# 💾 배치 저장: 5개 리뷰
# 📊 진행 상황: 190/477 (경과 1.7분)
# ➖ Qui staremo benissimo (tt28610700) 리뷰 없음
# ➖ Damned Old People (tt15829824) 리뷰 없음
# ✅ Some Like It Fake (tt38799964)  1/1개
# ➖ Friendship love (tt39088926) 리뷰 없음
# ➖ Fuori la verità (tt35301687) 리뷰 없음
# ➖ Наш папа – Дед Мороз! (tt31022276) 리뷰 없음
# ➖ Million (tt38111150) 리뷰 없음
# ➖ Fellow Travelers (tt37932062) 리뷰 없음
# ➖ Legionario (tt18830088) 리뷰 없음
# ➖ Milton Gonçalves, Além do Espetáculo (tt38504654) 리뷰 없음
# 💾 배치 저장: 1개 리뷰
# 📊 진행 상황: 200/477 (경과 1.8분)
# ➖ Kickback (tt38874091) 리뷰 없음
# ➖ Etty part 1 (tt27237072) 리뷰 없음
# ➖ Time We Lost (tt37150957) 리뷰 없음
# ➖ For Our Rights (tt33503888) 리뷰 없음
# ➖ Мой сын (tt33368707) 리뷰 없음
# ➖ A Movie Trip (tt35985946) 리뷰 없음
# ➖ Tomar Jonno Mon (tt38844702) 리뷰 없음
# ✅ To New Beginnings (tt38285001)  1/1개
# ➖ Emma karácsonya (tt38084609) 리뷰 없음
# ➖ I Love You, I Leave You (tt38065187) 리뷰 없음
# 💾 배치 저장: 1개 리뷰
# 📊 진행 상황: 210/477 (경과 1.8분)
# ➖ El Corazón (tt35048363) 리뷰 없음
# ➖ HUM (tt38915696) 리뷰 없음
# ✅ Santa Zeta (tt37833056)  3/3개
# ➖ El Correcaminos (tt32544293) 리뷰 없음
# ✅ My Mother Looked Just Like You (tt37888580)  1/1개
# ➖ Stefi (tt38915646) 리뷰 없음
# ➖ Lo Scuru (tt32919874) 리뷰 없음
# ➖ Little Man-Eater (tt38772835) 리뷰 없음
# ➖ Inherited Silence (tt38915614) 리뷰 없음
# ✅ Okean Elzy: Stormwatch (tt37845094)  2/2개
# 💾 배치 저장: 6개 리뷰
# 📊 진행 상황: 220/477 (경과 1.9분)
# ➖ Between Borders (tt38779953) 리뷰 없음
# ➖ The Growcodile (tt27788787) 리뷰 없음
# ➖ The Second Diary of Paulina P. (tt38598406) 리뷰 없음
# ✅ Scarecrow (tt36330330)  1/1개
# ➖ Austin Nasso: Impressionable Youth (tt38793736) 리뷰 없음
# ➖ SLASH S.E.R.P.E.N.T. Festival : Live from Denver (tt33039340) 리뷰 없음
# ➖ Without fear or guilt (tt38870518) 리뷰 없음
# ➖ About What? (tt35365242) 리뷰 없음
# ➖ Whispers of a Qareen (tt32937308) 리뷰 없음
# ➖ My Amma's Tale (tt34700801) 리뷰 없음
# 💾 배치 저장: 1개 리뷰
# 📊 진행 상황: 230/477 (경과 1.9분)
# ✅ Secondhand Miracles (tt38933512)  6/6개
# ➖ Left Unsaid (tt27827241) 리뷰 없음
# ➖ Rise of the Underdog (tt28608299) 리뷰 없음
# ➖ The Smoke that Thunders (tt38840439) 리뷰 없음
# ➖ Der Trans-Europ-Express TEE - Legende auf Schienen (tt38875918) 리뷰 없음
# ➖ UNTEN – Im Ortsverein (tt38801397) 리뷰 없음
# ➖ Whispers of Redemption (tt29293992) 리뷰 없음
# ➖ Bölöni – Az erdélyi legenda (tt38754861) 리뷰 없음
# ➖ Semillas (tt10460810) 리뷰 없음
# ✅ JUJUTSU KAISEN: Execution -Shibuya Incident x The Culling Game Begins- (tt38121182)  91/91개
# 💾 배치 저장: 97개 리뷰
# 📊 진행 상황: 240/477 (경과 2.0분)
# ✅ The Choral (tt31851518)  20/20개
# ✅ The Beldham (tt20254992)  15/15개
# ➖ Christmas Eve (tt8857166) 리뷰 없음
# ✅ Unexpected Christmas (tt34911155)  6/6개
# ✅ Aaromaley (tt36587142)  13/13개
# ➖ Love Live! Nijigasaki High School Idol Club Final Chapter Part 2 (tt36454732) 리뷰 없음
# ✅ I Wish You All the Best (tt22525442)  5/5개
# ✅ Long Shadows (tt21631810)  4/4개
# ➖ Home Sweet Home (tt32246406) 리뷰 없음
# ✅ In Your Dreams (tt27604215)  44/44개
# 💾 배치 저장: 107개 리뷰
# 📊 진행 상황: 250/477 (경과 2.1분)
# ➖ Nympho (tt38348188) 리뷰 없음
# ➖ Creature Fear (tt32131697) 리뷰 없음
# ➖ Kronos Kairos (tt38890314) 리뷰 없음
# ✅ Dragonfly (tt32383425)  3/3개
# ➖ The Fuzzies (tt17939784) 리뷰 없음
# ✅ Stone Cold Fox (tt27368237)  9/9개
# ➖ Solomamma (tt35485652) 리뷰 없음
# ✅ North (tt35485979)  4/4개
# ➖ Bi Umut (tt37025457) 리뷰 없음
# ➖ Two Seasons, Two Strangers (tt37538491) 리뷰 없음
# 💾 배치 저장: 16개 리뷰
# 📊 진행 상황: 260/477 (경과 2.1분)
# ➖ Leo & Lou (tt33098517) 리뷰 없음
# ✅ Exit Protocol (tt32421438)  4/4개
# ✅ Jassi Weds Jassi (tt37538305)  9/9개
# ➖ Yakushima's Illusion (tt36364208) 리뷰 없음
# ✅ Finding Hozho (tt9076126)  1/1개
# ➖ Reversion (tt35683787) 리뷰 없음
# ➖ The Gold Panner from Lannavaara (tt31701644) 리뷰 없음
# ✅ Innocent (tt34614859)  4/4개
# ✅ The Sun Rises on Us All (tt32907482)  2/2개
# ✅ The Girlfriend (tt29606526)  90/90개
# 💾 배치 저장: 110개 리뷰
# 📊 진행 상황: 270/477 (경과 2.2분)
# ➖ Deadline (tt38349157) 리뷰 없음
# ✅ Others (tt37897558)  4/4개
# ➖ Subsuelo (tt33034966) 리뷰 없음
# ➖ Lentävä kuolema (tt37919188) 리뷰 없음
# ➖ Jaari 2: Song of Chyabrung (tt38806549) 리뷰 없음
# ✅ Thieves Highway (tt32801387)  9/9개
# ✅ Krishna Leela (tt36873019)  1/1개
# ➖ Always Winter (tt33487489) 리뷰 없음
# ➖ The Obsessed (tt37061307) 리뷰 없음
# ➖ After All (tt8447852) 리뷰 없음
# 💾 배치 저장: 14개 리뷰
# 📊 진행 상황: 280/477 (경과 2.3분)
# ✅ Scott (tt19042642)  1/1개
# ✅ Jatadhara (tt32813410)  9/9개
# ✅ Happy Khush Ho Gaya (tt37896655)  1/1개
# ✅ Ithiri Neram (tt29668971)  4/4개
# ✅ Peter Hujar's Day (tt34250044)  5/5개
# ✅ All Is Merry & Bright (tt35069678)  4/4개
# ✅ I Am God (tt38775702)  1/1개
# ➖ Room Number (tt38342355) 리뷰 없음
# ✅ Ranna Baati (tt38077601)  4/4개
# ✅ Vattakhanal (tt38428591)  43/43개
# 💾 배치 저장: 72개 리뷰
# 📊 진행 상황: 290/477 (경과 2.3분)
# ➖ As Meninas Exemplares (tt30274237) 리뷰 없음
# ➖ We'll Find Happiness (tt31851883) 리뷰 없음
# ➖ All That We Love (tt10730122) 리뷰 없음
# ➖ Nine Auras (tt39064495) 리뷰 없음
# ✅ Odyssey (tt31227740)  4/4개
# ✅ The Great Pre-Wedding Show (tt33888205)  9/9개
# ➖ Premistunnaa (tt36812691) 리뷰 없음
# ➖ The Gap (tt39215074) 리뷰 없음
# ➖ Going to the Dogs (tt34633380) 리뷰 없음
# ✅ Chiranjeeva (tt38589147)  155/155개
# 💾 배치 저장: 168개 리뷰
# 📊 진행 상황: 300/477 (경과 2.4분)
# ➖ Parrisu (tt38682736) 리뷰 없음
# ➖ Africa Blanca (tt36575512) 리뷰 없음
# ➖ I Believe in Santa 2 (tt38705053) 리뷰 없음
# ✅ Don't Trip (tt27836391)  3/3개
# ➖ Plankenstein: A Killer Surf Movie (tt30229624) 리뷰 없음
# ✅ Lost & Found in Cleveland (tt4601732)  20/20개
# ➖ 3 Cold Dishes (tt36643696) 리뷰 없음
# ✅ Delupi (tt38671864)  3/3개
# ➖ Badaa Karara Pudna (tt38598593) 리뷰 없음
# ✅ Stripper Boyz (tt32769461)  1/1개
# 💾 배치 저장: 27개 리뷰
# 📊 진행 상황: 310/477 (경과 2.4분)
# ➖ Monikondee (tt36242352) 리뷰 없음
# ➖ Red Market (tt26670480) 리뷰 없음
# ➖ Her Kiss, My Libido Twinkles (tt38639811) 리뷰 없음
# ➖ Sovereign (tt33060769) 리뷰 없음
# ➖ While It Lasts (tt34748262) 리뷰 없음
# ✅ Destroy This Tape (tt36456038)  11/11개
# ➖ Jay Jurden: Yes Ma'am (tt38129244) 리뷰 없음
# ➖ White Lies (tt35835860) 리뷰 없음
# ➖ Cinemortal (tt28093172) 리뷰 없음
# ✅ Kadhipatta (tt36754288)  31/31개
# 💾 배치 저장: 42개 리뷰
# 📊 진행 상황: 320/477 (경과 2.5분)
# ➖ Endless Land (tt35101414) 리뷰 없음
# ✅ Caterpillar (tt26593617)  1/1개
# ➖ Get Out (tt38881356) 리뷰 없음
# ➖ Bullet Train The Movie RE:VE (tt38873841) 리뷰 없음
# ✅ A Home for Christmas (tt34129262)  4/4개
# ➖ Nothing to Lose (tt38510825) 리뷰 없음
# ➖ Ian Lara: Material Boy (tt38909928) 리뷰 없음
# ➖ The Swede of Philadelphia (tt37511710) 리뷰 없음
# ➖ Astra La Vista (tt38496386) 리뷰 없음
# ✅ Fragilé (tt38689606)  1/1개
# 💾 배치 저장: 6개 리뷰
# 📊 진행 상황: 330/477 (경과 2.5분)
# ➖ Sunset Memory (tt29494368) 리뷰 없음
# ➖ The Taking of Courtroom One Two Three (tt33336755) 리뷰 없음
# ➖ The Marbles (tt12736326) 리뷰 없음
# ➖ THRESHOLD (tt38974404) 리뷰 없음
# ✅ The Decedent (tt38671331)  5/5개
# ➖ Reality TV Murders (tt36651426) 리뷰 없음
# ➖ Toritori and the Secret of the Baby Dino (tt38945424) 리뷰 없음
# ✅ SCARECROW (tt36333651)  1/1개
# ➖ The Lights: Test Run (tt38716286) 리뷰 없음
# ➖ Tempo Rubato (tt35591720) 리뷰 없음
# 💾 배치 저장: 6개 리뷰
# 📊 진행 상황: 340/477 (경과 2.6분)
# ➖ Emi (tt38779913) 리뷰 없음
# ➖ Yesterday I Dreamed (tt39185732) 리뷰 없음
# ➖ Exhibiting Avery (tt37557579) 리뷰 없음
# ➖ Colossal Wreck (tt38889640) 리뷰 없음
# ➖ Fer & Pipo (tt37778930) 리뷰 없음
# ➖ Pray for me: Pope Francis' story (tt37194968) 리뷰 없음
# ➖ Westbound (tt38742870) 리뷰 없음
# ➖ Hummus (tt32324198) 리뷰 없음
# ➖ Teeth (tt38644376) 리뷰 없음
# ✅ Saipan (tt33093531)  3/3개
# 💾 배치 저장: 3개 리뷰
# 📊 진행 상황: 350/477 (경과 2.6분)
# ➖ Accomplices (tt32904302) 리뷰 없음
# ➖ Craggy Confidant (tt31971226) 리뷰 없음
# ➖ Born Secret (tt33365151) 리뷰 없음
# ➖ Call it Fate (tt34884023) 리뷰 없음
# ✅ Zombie Apache (tt32313670)  5/5개
# ➖ Malaki Duwe Numba (tt37435884) 리뷰 없음
# ➖ Oneiros (tt34754185) 리뷰 없음
# ➖ Fatum (tt34932437) 리뷰 없음
# ➖ Giants (tt38736710) 리뷰 없음
# ✅ Christmas Above the Clouds (tt38183872)  34/34개
# 💾 배치 저장: 39개 리뷰
# 📊 진행 상황: 360/477 (경과 2.7분)
# ➖ Nothing Personal (tt15487888) 리뷰 없음
# ✅ Candy (tt33507467)  1/1개
# ➖ Haloom (tt35884989) 리뷰 없음
# ➖ 2025 Rock & Roll Hall of Fame Induction Ceremony (tt38263655) 리뷰 없음
# ➖ His Monster (tt28595505) 리뷰 없음
# ➖ Behind The Door (tt29635136) 리뷰 없음
# ➖ Terry McMillan Presents: Preach, Pray, Love (tt38895958) 리뷰 없음
# ➖ Pinjar (tt38778357) 리뷰 없음
# ➖ Receptions (tt32447813) 리뷰 없음
# ➖ Ridiculous Loves (tt36932214) 리뷰 없음
# 💾 배치 저장: 1개 리뷰
# 📊 진행 상황: 370/477 (경과 2.7분)
# ➖ Ones Left Behind (tt38984325) 리뷰 없음
# ➖ What's Up with Secretary Kim? (tt38721745) 리뷰 없음
# ➖ The Feast of the Wolf (tt38606466) 리뷰 없음
# ➖ Oxidado (tt32104505) 리뷰 없음
# ➖ A Grandfather (tt38573751) 리뷰 없음
# ➖ Dragon Girl Problem (tt38994021) 리뷰 없음
# ➖ Earth (tt38060904) 리뷰 없음
# ➖ Moral Hazard (tt36934566) 리뷰 없음
# ➖ Mr TV Man (tt33090774) 리뷰 없음
# ➖ Broken Courage (tt12262260) 리뷰 없음
# 📊 진행 상황: 380/477 (경과 2.8분)
# ➖ The Escort (tt38934582) 리뷰 없음
# ➖ L'héritier des secrets (tt33131498) 리뷰 없음
# ➖ Sojelfer (tt31987807) 리뷰 없음
# ➖ Els Mals Noms (tt31639422) 리뷰 없음
# ➖ Penguins of the Point (tt38566145) 리뷰 없음
# ✅ Jiaoying Summers: What Species Are You? (tt38129252)  2/2개
# ➖ King of the Mountains (tt34755438) 리뷰 없음
# ➖ The Architect (tt35624719) 리뷰 없음
# ➖ La madre de Dreyer (tt38783051) 리뷰 없음
# ➖ The Brain That Cried Wolf (tt36872449) 리뷰 없음
# 💾 배치 저장: 2개 리뷰
# 📊 진행 상황: 390/477 (경과 2.8분)
# ➖ Dependency (tt38891042) 리뷰 없음
# ➖ The Last Prometheus of Donbas (tt38961946) 리뷰 없음
# ➖ La  Terra Sin Mal (tt36372389) 리뷰 없음
# ✅ Song of the Selkie (tt19878418)  1/1개
# ➖ Memento Mori (tt32982175) 리뷰 없음
# ➖ Bellydance Vogue (tt13158814) 리뷰 없음
# ➖ I just want to hear her voice (tt31216686) 리뷰 없음
# ➖ muita gente (tt38895419) 리뷰 없음
# ➖ The Hat (tt22498414) 리뷰 없음
# ➖ Our Tender Moment (tt36364624) 리뷰 없음
# 💾 배치 저장: 1개 리뷰
# 📊 진행 상황: 400/477 (경과 2.9분)
# ➖ Living in Hanna (tt35673727) 리뷰 없음
# ➖ Return of the Fireflies (tt38534175) 리뷰 없음
# ➖ Doremi Dalimi (tt38945567) 리뷰 없음
# ➖ Only One Glove (tt37263757) 리뷰 없음
# ➖ El Refugio (tt38968465) 리뷰 없음
# ➖ Miss Jobson (tt38715237) 리뷰 없음
# ➖ The Peril of the Wild West (tt37898538) 리뷰 없음
# ➖ Shasha & Milo (tt38945565) 리뷰 없음
# ➖ Cats Are Masters of the World (tt38945559) 리뷰 없음
# ➖ Las Sábanas de Marruecos (tt33998381) 리뷰 없음
# 📊 진행 상황: 410/477 (경과 2.9분)
# ✅ Under the Stars (tt31614921)  3/3개
# ➖ My Movie Starring Paul Dano (tt31353594) 리뷰 없음
# ✅ A Keller Christmas Vacation (tt38353730)  14/14개
# ➖ Alphas (tt34512197) 리뷰 없음
# ➖ LS83 (tt36220449) 리뷰 없음
# ➖ Black Hole (tt38503735) 리뷰 없음
# ➖ Das Märchen vom Schwanensee (tt38966218) 리뷰 없음
# ➖ Lucifer's Case (tt32655967) 리뷰 없음
# ➖ The Left Hand (tt19842750) 리뷰 없음
# ➖ Technophobic (tt38456962) 리뷰 없음
# 💾 배치 저장: 17개 리뷰
# 📊 진행 상황: 420/477 (경과 3.0분)
# ➖ The Untethering (tt39074683) 리뷰 없음
# ➖ Mediator (tt38630428) 리뷰 없음
# ✅ Bo Johnson: Two Sailboats (tt38906524)  5/5개
# ✅ A Royal Christmas Manor (tt30797225)  1/1개
# ➖ Late Night Call (tt37727122) 리뷰 없음
# ➖ Birds Two by Two (tt37367867) 리뷰 없음
# ➖ Chemical Egg (tt38952433) 리뷰 없음
# ➖ Hive (tt1778360) 리뷰 없음
# ➖ It's Winter (tt38735775) 리뷰 없음
# ➖ Days of Wonder (tt36982139) 리뷰 없음
# 💾 배치 저장: 6개 리뷰
# 📊 진행 상황: 430/477 (경과 3.0분)
# ➖ A Queen in Carcosa (tt38381099) 리뷰 없음
# ➖ The Disappearance of Captain Nairac (tt38624854) 리뷰 없음
# ➖ Plaza Nueva a las diez (tt38639518) 리뷰 없음
# ➖ An Interview with the Devil (tt38606800) 리뷰 없음
# ➖ No Barriers (tt38820713) 리뷰 없음
# ➖ Farming on the Edge (tt36988190) 리뷰 없음
# ➖ Through Your Eyes (tt38279537) 리뷰 없음
# ➖ La cosa en la niebla (tt35650334) 리뷰 없음
# ➖ The Silent Choice (tt30623820) 리뷰 없음
# ➖ The Spinning Wheel (tt38046260) 리뷰 없음
# 📊 진행 상황: 440/477 (경과 3.0분)
# ➖ The Missing Part (tt37434138) 리뷰 없음
# ➖ SHE LIVES AT SCHOOL (tt38672182) 리뷰 없음
# ➖ The Jokes on You (tt38492410) 리뷰 없음
# ✅ Beyond the Drumlins (tt36164099)  2/2개
# ➖ Ricochet (tt35487940) 리뷰 없음
# ✅ A Table For Two (tt38875955)  2/2개
# ➖ Only When You Bury Me In This Earth (tt28308161) 리뷰 없음
# ➖ Soft Floating in the Fields of Spheres (tt12302590) 리뷰 없음
# ➖ Crayons (tt38934511) 리뷰 없음
# ✅ A Very Jonas Christmas Movie (tt35600079)  55/55개
# 💾 배치 저장: 59개 리뷰
# 📊 진행 상황: 450/477 (경과 3.1분)
# ➖ Due Dating (tt23791194) 리뷰 없음
# ✅ Christmas Flame (tt12847168)  8/8개
# ➖ Israel: Ministers of Chaos (tt33415663) 리뷰 없음
# ✅ The War Between (tt25715918)  10/10개
# ✅ A Holiday Short: Best Christmas Ever (tt38909003)  1/1개
# ➖ I Love Lucca Comics & Games (tt38639850) 리뷰 없음
# ➖ Bendito corazón (tt34937388) 리뷰 없음
# ➖ Mountains of Fire (tt36454397) 리뷰 없음
# ➖ Richard Burton: Wild Genius (tt38907872) 리뷰 없음
# ➖ Salt i Sammet (tt38891078) 리뷰 없음
# 💾 배치 저장: 19개 리뷰
# 📊 진행 상황: 460/477 (경과 3.2분)
# ➖ Forest Bathers (tt34247445) 리뷰 없음
# ✅ A Winter's Song (tt29044868)  2/2개
# ➖ All this sky (tt25274228) 리뷰 없음
# ➖ Piero Pelù - Rumore dentro (tt37660877) 리뷰 없음
# ➖ Toni, My Father (tt38068969) 리뷰 없음
# ➖ A Seat at the Table (tt38120957) 리뷰 없음
# ➖ Risa and the Wind Phone (tt38871399) 리뷰 없음
# ➖ Harmonious (tt38230605) 리뷰 없음
# ➖ The Last 600 Meters: The Battles of Najaf and Fallujah (tt3485402) 리뷰 없음
# ➖ cataclysm.begins: The Catalyst (tt13194254) 리뷰 없음
# 💾 배치 저장: 2개 리뷰
# 📊 진행 상황: 470/477 (경과 3.2분)
# ➖ Miguel's Reflection (tt38173824) 리뷰 없음
# ➖ Fish Out of Water (tt37244006) 리뷰 없음
# ➖ Attack of the Scary Thing from the Dangerous Lake (tt38913488) 리뷰 없음
# ➖ Sentence of 15 (tt32466280) 리뷰 없음
# ➖ Fuck jeg elsker dig (tt33111820) 리뷰 없음
# ➖ We are Greenland: Football Is Freedom (tt37644735) 리뷰 없음
# ➖ Jake & Pete’s Christmas Special (tt31249703) 리뷰 없음
# 📊 진행 상황: 477/477 (경과 3.2분)
#
# ✅ 크롤링 완료
# ⏱️ 총 소요 시간: 3.2분

# %%
await idc.collect_imdb_ratings(
    input_csv_path=f"{OUTPUT_DIR}/movies_test.csv",   # 아까 만든 5035편 리스트
    output_csv_path=f"{OUTPUT_DIR}/movies_rating_test.csv",   # 최종 점수 파일
)
# Out:
# ==========================================================================================
# 🚀 IMDB RATING COLLECTOR (2005-2015)
# ==========================================================================================
#
# 📂 데이터 로드 중...
# ⚠️  'first_air_date' 컬럼이 없습니다. 날짜 필터링을 건너뜁니다.
# ✅ 최종 필터링 (vote_count>=30 & imdb_id 존재): 12개
#
# 🚀 크롤링 시작
# ⚙️  Rate Limit: 2회/초
# ⏱️  예상 시간: 0분
# 📊 진행: 10/12 (83.3%) | 성공: 10 | 실패: 0 | 요청: 10회 | 속도: 163.6개/분 | ETA: 0분
# 📊 진행: 12/12 (100.0%) | 성공: 12 | 실패: 0 | 요청: 12회 | 속도: 135.8개/분 | ETA: 0분
#
# 💾 최종 저장 중...
#
# ==========================================================================================
# 🎉 크롤링 완료!
# ==========================================================================================
# 📌 시리즈: 12/12개 성공
# 📌 총 수집: 12개 (중복 제거 후)
# 📌 Rating 보유: 12개 (100.0%)
# 📌 평균 Rating: 6.21
# 📌 평균 Rating Count: 14578
# 📌 총 요청: 12회
# ⏱️  총 시간: 0.1분 (0.00시간)
# 📊 속도: 135.6개/분
# ==========================================================================================
#
# 📊 결과 샘플:
#       imdb_id  imdb_rating  imdb_rating_count
# 0  tt31227572          7.3              63021
# 1  tt31425731          5.5              20829
# 2  tt29768334          7.5              36596
# 3  tt31193547          4.6                971
# 4  tt32398150          7.1                489
# 5  tt29567915          7.5              27195
# 6  tt32323252          6.2              11289
# 7  tt33293169          5.7               1780
# 8  tt38121182          6.5               3303
# 9  tt27604215          6.5               5047
#
# ✅ 결과 파일: files/movies_rating_test.csv

# %%
await idc.collect_imdb_reviews(
    input_csv_path=f"{OUTPUT_DIR}/tv_series_test.csv",   # 아까 만든 5035편 리스트
    output_csv_path=f"{OUTPUT_DIR}/reviews/tv_reviews_test.csv",   # 최종 리뷰 파일
    max_titles=None,               # 전체 5035편 다 돌리기
    max_reviews_per_title=None     # 영화당 리뷰 전부 수집
)
# Out:
# ======================================================================
# 🚀 IMDb 리뷰 크롤링 시작
# 📂 입력: files/tv_series_test.csv
# 💾 출력: files/reviews/tv_reviews_test.csv
# ======================================================================
# 📌 기존 리뷰 파일 발견 → 이미 수집된 imdb_id 스킵
#    이미 수집된 영화 수: 57
# 🎯 이번에 수집할 영화 수: 54
# ➖ Dead End (tt32583026) 리뷰 없음
# ➖ Μία Νύχτα Μονο (tt38493618) 리뷰 없음
# ➖ Detective Naveed (tt32150299) 리뷰 없음
# ➖ L'appartamento - Sold Out (tt35663177) 리뷰 없음
# ➖ It's Time - E' Giunta L'ora (tt38111441) 리뷰 없음
# ➖ Het Zwaard van Damocles (tt38832337) 리뷰 없음
# ➖ A Happy Place (tt38961906) 리뷰 없음
# ➖ Lonely Hero (tt33365220) 리뷰 없음
# ➖ Holiday Bakeshop (tt38581726) 리뷰 없음
# ➖ Break from Apocalypse (tt38221468) 리뷰 없음
# 📊 진행 상황: 10/54 (경과 0.0분)
# ➖ Decalcomania (tt32880015) 리뷰 없음
# ➖ Hirayasumi (tt37810816) 리뷰 없음
# ➖ Wild Bees (tt38592526) 리뷰 없음
# ➖ Jagten på Danmarkshistorien (tt39151074) 리뷰 없음
# ➖ FAME/LESS (tt15783240) 리뷰 없음
# ➖ MDRJago: Bendies Rising (tt38626697) 리뷰 없음
# ➖ Mondes sauvages (tt38839652) 리뷰 없음
# ➖ Runaway (tt37342224) 리뷰 없음
# ➖ Soul Sucker (tt35669589) 리뷰 없음
# ➖ Sandi Toksvig's Hidden Wonders (tt38813959) 리뷰 없음
# 📊 진행 상황: 20/54 (경과 0.1분)
# ➖ Mälzers Meisterklasse (tt36327631) 리뷰 없음
# ➖ Blemish Flaw (tt38808143) 리뷰 없음
# ➖ Scav (tt36737655) 리뷰 없음
# ➖ Нам покер (tt36071588) 리뷰 없음
# ➖ Tournament of Champions: All-Star Christmas (tt38866811) 리뷰 없음
# ➖ The Marsupilamis (tt10773162) 리뷰 없음
# ➖ Roktowrin (tt36130057) 리뷰 없음
# ➖ Steam Train Diaries (tt38780014) 리뷰 없음
# ➖ Corazón salvaje (tt0266130) 리뷰 없음
# ➖ My Ayrton, by Adriane Galisteu (tt4335524) 리뷰 없음
# 📊 진행 상황: 30/54 (경과 0.1분)
# ➖ Kaikki rakastavat hevosia (tt35488252) 리뷰 없음
# ➖ Animales en peligro (tt38993929) 리뷰 없음
# ➖ The Wives Did It (tt5160824) 리뷰 없음
# ➖ Karma (tt38896081) 리뷰 없음
# ➖ Interminable (tt34935151) 리뷰 없음
# ➖ SEVENTEEN: OUR CHAPTER (tt38776655) 리뷰 없음
# ➖ Those Days (tt33410969) 리뷰 없음
# ➖ Network (tt37678040) 리뷰 없음
# ➖ The other gAirl (tt37545261) 리뷰 없음
# ➖ Baby Shu and Fwends (tt38773990) 리뷰 없음
# 📊 진행 상황: 40/54 (경과 0.2분)
# ➖ Dino Ranch: Island Explorers (tt34461484) 리뷰 없음
# ➖ FUTURE KID TAKARA (tt38046507) 리뷰 없음
# ➖ It's Bunlith! The Witch Upstairs (tt38893686) 리뷰 없음
# ➖ Hermitcraft Season 11 (tt10123950) 리뷰 없음
# ➖ Calciopoli ultimo atto: le nuove verità nascoste (tt37445809) 리뷰 없음
# ➖ Aşkın Gücü (tt24060116) 리뷰 없음
# ➖ Don't Call Me Ma'am (tt38839105) 리뷰 없음
# ➖ My hidden truth (tt38207646) 리뷰 없음
# ➖ Camino a Arcadia (tt32367823) 리뷰 없음
# ➖ Bill Bailey’s Vietnam (tt38973463) 리뷰 없음
# 📊 진행 상황: 50/54 (경과 0.2분)
# ➖ Most Wanted - A hajsza (tt38915987) 리뷰 없음
# ➖ Химкинские ведьмы (tt38517018) 리뷰 없음
# ➖ Annabel Crabb's Civic Duty (tt38895810) 리뷰 없음
# ➖ NeuroVasya (tt34807653) 리뷰 없음
# 📊 진행 상황: 54/54 (경과 0.2분)
#
# ✅ 크롤링 완료
# ⏱️ 총 소요 시간: 0.2분

# %%
await idc.collect_imdb_ratings(
    input_csv_path=f"{OUTPUT_DIR}/tv_series_test.csv",
    output_csv_path=f"{OUTPUT_DIR}/tv_series_rating_test.csv",
)
# Out:
# ==========================================================================================
# 🚀 IMDB RATING COLLECTOR (2005-2015)
# ==========================================================================================
#
# 📂 데이터 로드 중...
# 📅 날짜 필터링: 2005-01-01 ~ 2025-12-31
#    원본: 384개 → 필터링 후: 384개
# ✅ 최종 필터링 (vote_count>=30 & imdb_id 존재): 10개
#
# 🚀 크롤링 시작
# ⚙️  Rate Limit: 2회/초
# ⏱️  예상 시간: 0분
# 📊 진행: 10/10 (100.0%) | 성공: 10 | 실패: 0 | 요청: 10회 | 속도: 142.9개/분 | ETA: 0분
#
# 💾 최종 저장 중...
#
# ==========================================================================================
# 🎉 크롤링 완료!
# ==========================================================================================
# 📌 시리즈: 10/10개 성공
# 📌 총 수집: 10개 (중복 제거 후)
# 📌 Rating 보유: 10개 (100.0%)
# 📌 평균 Rating: 7.22
# 📌 평균 Rating Count: 13338
# 📌 총 요청: 10회
# ⏱️  총 시간: 0.1분 (0.00시간)
# 📊 속도: 142.5개/분
# ==========================================================================================
#
# 📊 결과 샘플:
#       imdb_id  imdb_rating  imdb_rating_count
# 0  tt33484460          6.5               3917
# 1  tt30291387          3.4              10058
# 2  tt36188448          7.8               3203
# 3  tt32253092          7.8               3554
# 4  tt22202452          8.1              72714
# 5  tt37890201          7.8               1950
# 6  tt31121364          7.7              12645
# 7  tt31314751          7.5              20735
# 8  tt33550045          7.5               2667
# 9  tt38491451          8.1               1940
#
# ✅ 결과 파일: files/tv_series_rating_test.csv

# %% [markdown]
# # 전처리

# %% [markdown]
# ## 파일 전처리

# %%
import preprocessing.text as pt

movie_data = pd.read_csv(f"{OUTPUT_DIR}/movies_test.csv")
movie_rating = pd.read_csv(f"{OUTPUT_DIR}/movies_rating_test.csv")

movie_data = movie_data.merge(movie_rating, on="imdb_id", how="left")

drama_data = pd.read_csv(f"{OUTPUT_DIR}/tv_series_test.csv")
drama_rating = pd.read_csv(f"{OUTPUT_DIR}/tv_series_rating_test.csv")

drama_data = drama_data.merge(movie_rating, on="imdb_id", how="left")

# %%
# 사용법
movie_prep = pt.DataPreprocessor(type='movie')
movie_prep.preprocess(movie_data)
movie_prep.save(f'{OUTPUT_DIR}/movie')

drama_prep = pt.DataPreprocessor(type='tv')
drama_prep.preprocess(drama_data)
drama_prep.save(f'{OUTPUT_DIR}/drama')
# Out:
#   ✓ files/movie/00_movie_main.parquet
#   ✓ files/movie/01_movie_roi.parquet
#   ✓ files/movie/02_movie_production_countries.parquet
#   ✓ files/movie/03_movie_genres.parquet
#   ✓ files/movie/04_movie_providers.parquet
#   ✓ files/drama/00_tv_main.parquet
#   ✓ files/drama/02_tv_origin_countries.parquet
#   ✓ files/drama/03_tv_genres.parquet
#   ✓ files/drama/04_tv_providers.parquet

# %%
movie_review = pd.read_csv(f"{OUTPUT_DIR}/reviews/movies_reviews_test.csv")
drama_review = pd.read_csv(f"{OUTPUT_DIR}/reviews/tv_reviews_test.csv")
review = pd.concat([movie_review, drama_review])

# %%
movie_prep = pt.ReviewPreprocessor(english_threshold=0.9)
clean_reviews = movie_prep.preprocess(review)
movie_prep.save(f'{OUTPUT_DIR}/reviews/reviews_test.parquet')
# Out:
# ▶ 텍스트 노이즈 제거 시작: 6,457개 행
#   - 제거된 행: 44개
#   - 남은 행: 6,413개

# %% [markdown]
# ## 흥행 점수 계산

# %%
import preprocessing.scoring as sc
import preprocessing.sentiment as sp

# %%
movie_main = pd.read_parquet(f"{OUTPUT_DIR}/movie/00_movie_main.parquet")
tv_main = pd.read_parquet(f"{OUTPUT_DIR}/drama/00_tv_main.parquet")
main = pd.concat([
    movie_main[['imdb_id', 'tmdb_rating', 'tmdb_rating_count', 'imdb_rating', 'imdb_rating_count']],
    tv_main[['imdb_id', 'tmdb_rating', 'tmdb_rating_count', 'imdb_rating', 'imdb_rating_count']]
])
review = pd.read_parquet(f"{OUTPUT_DIR}/reviews/reviews_test.parquet")

# %%
analyzer = sp.SentimentAnalyzer()
analyzer.analyze(review, f"{OUTPUT_DIR}/reviews", text_column="review_text")
# Out:
# ▶ Total rows: 6,413
# ▶ Total chunks: 1
# ▶ Existing chunks: 0 (will skip)
# [2025-12-28 20:37:02] === SENTIMENT ANALYSIS START ===
# [2025-12-28 20:37:02] CHUNK 0/0 - rows=6,413, range=[0:6,413]
# [2025-12-28 20:49:52] CHUNK 00000 - DONE(12.83 min, 8.3 rows/sec) -> files/reviews/review_chunk_00000.parquet
# [2025-12-28 20:49:52] === SENTIMENT ANALYSIS COMPLETED ===
#
# ✅ All chunks processed successfully!

# %%
review = pd.read_parquet(f"{OUTPUT_DIR}/reviews/review_chunk_00000.parquet").merge(pd.read_parquet(f"{OUTPUT_DIR}/reviews/reviews_test.parquet")[['helpful_ratio', 'review_id']], on='review_id', how='left')

# %%
sentiment_score = sc.compute_weighted_sentiment_score(review)
main_score = sc.calculate_ratings(main)

# %%
sc.calculate_score(main_score.merge(sentiment_score, on='imdb_id', how='inner'))
# Out:
#       imdb_id  hit_score
# 0  tt31227572  40.101378
# 1  tt31425731  31.025830
# 2  tt29768334  44.858438
# 3  tt31193547  16.817422
# 4  tt29567915  39.010789
# 5  tt32323252  35.887938
# 6  tt33293169  20.300631
# 7  tt38121182  18.700524
# 8  tt27604215  35.679517
# 9  tt35600079  31.486951
